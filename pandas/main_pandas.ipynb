# %% [markdown]
# # Working With Pandas Library

# %%
import pandas as pd

# %%
#create of table ( Data Frame df)
data = {
    "name":["saeed","sajad","hasan"],
    "age":[26,22,31]
}
df =pd.DataFrame(data)
df
# Out:
#     name  age
# 0  saeed   26
# 1  sajad   22
# 2  hasan   31

# %%
#Read 
df=pd.read_csv("./data.csv")
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k

# %%
df.head() # return 5 rows of all
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k

# %%
df.describe()
# Out:
#              age
# count   9.000000
# mean   23.000000
# std     2.291288
# min    21.000000
# 25%    21.000000
# 50%    22.000000
# 75%    26.000000
# max    26.000000

# %%
df['name']
# Out:
# 0    saeed
# 1    sajad
# 2    hanie
# 3        x
# 4        y
# 5        z
# 6        1
# 7        2
# 8        3
# Name: name, dtype: object

# %%
df.iloc[2,:]
# Out:
# name      hanie
# age          21
# salary      30k
# Name: 2, dtype: object

# %%
#filltering data
filltered_df = df[df["age"]>21]
filltered_df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 3      x   26    32k
# 4      y   22    22k
# 6      1   26    32k
# 7      2   22    22k

# %%
#sort
df_sorted=df.sort_values("age" ,ascending=False)
df_sorted
# Out:
#     name  age salary
# 0  saeed   26    32k
# 3      x   26    32k
# 6      1   26    32k
# 1  sajad   22    22k
# 4      y   22    22k
# 7      2   22    22k
# 2  hanie   21    30k
# 5      z   21    30k
# 8      3   21    30k

# %%
#subset
subset = df.loc[2:4,["age","salary"]]
subset
# Out:
#    age salary
# 2   21    30k
# 3   26    32k
# 4   22    22k

# %%
#group
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k

# %%
df_grouped= df.groupby("age")
df_grouped.count()
# Out:
#      name  salary
# age
# 21      3       3
# 22      3       3
# 26      3       3

# %%
#add new col
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k

# %%
df["newcol"]=[1,2,3,4,5,6,7,8,9]
df
# Out:
#     name  age salary  newcol
# 0  saeed   26    32k       1
# 1  sajad   22    22k       2
# 2  hanie   21    30k       3
# 3      x   26    32k       4
# 4      y   22    22k       5
# 5      z   21    30k       6
# 6      1   26    32k       7
# 7      2   22    22k       8
# 8      3   21    30k       9

# %%
#delete col 
df.drop("newcol",axis=1,inplace=True)
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k

# %%
# add new row
df.loc[len(df)]={
    "name":"test",
    "age":25
}
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k
# 9   test   25    NaN

# %%
# finding is NaN 
df.isna()
# Out:
#     name    age  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False   False
# 8  False  False   False
# 9  False  False    True

# %%
#delete is nan
df =df.dropna() # or we can fill it using fillna()
df
# Out:
#     name  age salary
# 0  saeed   26    32k
# 1  sajad   22    22k
# 2  hanie   21    30k
# 3      x   26    32k
# 4      y   22    22k
# 5      z   21    30k
# 6      1   26    32k
# 7      2   22    22k
# 8      3   21    30k

# %%
#write
df.to_csv("new_data.csv")
